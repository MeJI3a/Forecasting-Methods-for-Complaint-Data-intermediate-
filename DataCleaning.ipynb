# %% [markdown]
# # 1. Cleaning and Processing Consumer Complaints Dataset
#
# ## Introduction
#
# This dataset represents consumer complaints about financial products and services collected by the Consumer Financial Protection Bureau (CFPB). The dataset includes information on the type of product, issue, company response, and more.
#
# The purpose of this part of the project is to clean and process the first of three datasets. This dataset requires:
#
# 1. **Data Inspection**: Understanding its structure and identifying key fields.
# 2. **Data Cleaning**: Removing duplicates, handling missing values, and ensuring consistent formatting.
# 3. **Feature Preparation**: Preparing fields for further analysis and integration with other files.
#
# This work is the foundation for integrating and analyzing multiple datasets, enabling meaningful insights into consumer financial complaints.

# %%
import numpy as np
import pandas as pd
import json
import os

# %%
# Define the file path
file_path = r'C:\Users\Zana\Desktop\portfolio_projects\project_4\complaints.json'

# %%
# Load the JSON data into a pandas DataFrame
with open(file_path, 'r') as f:
    data = json.load(f)

# %%
# If the JSON structure is flat (list of dictionaries), you can directly create a DataFrame
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#    took  timed_out  _shards.total  _shards.successful  _shards.skipped  \
# 0  1373      False              5                   5                0
#
#    _shards.failed  hits.total.value hits.total.relation hits.max_score  \
# 0               0           3093136                  eq           None
#
#                                            hits.hits  ...  \
# 0  [{'_index': 'complaint-public-v1', '_type': '_...  ...
#
#    _meta.total_record_count  _meta.is_data_stale  _meta.has_data_issue  \
# 0                   3093136                False                 False
#
#   _meta.break_points.2  _meta.break_points.3  _meta.break_points.4  \
# 0        [1.0, 999878]          [1.0, 99976]         [1.0, 999652]
#
#    _meta.break_points.5 _meta.break_points.6  _meta.break_points.7  \
# 0         [1.0, 999589]        [1.0, 999492]         [1.0, 999398]
#
#    _meta.break_points.8
# 0          [1.0, 99928]
#
# [1 rows x 67 columns]

# %% [markdown]
# # Inspected Raw JSON Structure

# %%
# Load and inspect the raw JSON data
import json

file_path = r'C:\Users\Zana\Desktop\portfolio_projects\project_4\complaints.json'

# Open the file and print the first few entries
with open(file_path, 'r') as f:
    data = json.load(f)

# Print the first few entries or keys
print(json.dumps(data, indent=4))  # Pretty print the JSON structure
# Out:
# {
#     "took": 1373,
#     "timed_out": false,
#     "_shards": {
#         "total": 5,
#         "successful": 5,
#         "skipped": 0,
#         "failed": 0
#     },
#     "hits": {
#         "total": {
#             "value": 3093136,
#             "relation": "eq"
#         },
#         "max_score": null,
#         "hits": [
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99999",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Bank account or service",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2013-11-18T12:00:00-05:00",
#                     "issue": "Deposits and withdrawals",
#                     "sub_product": "Checking account",
#                     "zip_code": "94605",
#                     "tags": "Older American",
#                     "has_narrative": false,
#                     "complaint_id": "99999",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Phone",
#                     "company": "WELLS FARGO & COMPANY",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "CA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99999"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999988",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Debt collection",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-09-04T12:00:00-05:00",
#                     "issue": "Communication tactics",
#                     "sub_product": "I do not know",
#                     "zip_code": "93305",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999988",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed",
#                     "submitted_via": "Web",
#                     "company": "Kimball, Tirey & St. John LLP",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "CA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": "Used obscene/profane/abusive language"
#                 },
#                 "sort": [
#                     1.0,
#                     "999988"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999986",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Mortgage",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Application, originator, mortgage broker",
#                     "sub_product": "Conventional fixed mortgage",
#                     "zip_code": "32818",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999986",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Phone",
#                     "company": "JPMORGAN CHASE & CO.",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "FL",
#                     "consumer_disputed": "Yes",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999986"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99998",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit card",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-06-15T12:00:00-05:00",
#                     "issue": "Advertising and marketing",
#                     "sub_product": null,
#                     "zip_code": "98221",
#                     "tags": "Older American",
#                     "has_narrative": false,
#                     "complaint_id": "99998",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Web",
#                     "company": "CAPITAL ONE FINANCIAL CORPORATION",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "WA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99998"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99997",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Bank account or service",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-06-21T12:00:00-05:00",
#                     "issue": "Problems caused by my funds being low",
#                     "sub_product": "Checking account",
#                     "zip_code": "19140",
#                     "tags": "Older American, Servicemember",
#                     "has_narrative": false,
#                     "complaint_id": "99997",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed",
#                     "submitted_via": "Postal mail",
#                     "company": "SANTANDER BANK, NATIONAL ASSOCIATION",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "PA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99997"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999966",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit reporting",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-25T12:00:00-05:00",
#                     "issue": "Unable to get credit report/credit score",
#                     "sub_product": null,
#                     "zip_code": "39503",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999966",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with non-monetary relief",
#                     "submitted_via": "Web",
#                     "company": "EQUIFAX, INC.",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "MS",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": "Problem getting my free annual report"
#                 },
#                 "sort": [
#                     1.0,
#                     "999966"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99996",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Bank account or service",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-06-18T12:00:00-05:00",
#                     "issue": "Account opening, closing, or management",
#                     "sub_product": "Savings account",
#                     "zip_code": "11375",
#                     "tags": "Older American",
#                     "has_narrative": false,
#                     "complaint_id": "99996",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with monetary relief",
#                     "submitted_via": "Phone",
#                     "company": "HSBC NORTH AMERICA HOLDINGS INC.",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "NY",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99996"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999958",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit reporting",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-09-23T12:00:00-05:00",
#                     "issue": "Incorrect information on credit report",
#                     "sub_product": null,
#                     "zip_code": "76124",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999958",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Postal mail",
#                     "company": "EQUIFAX, INC.",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "TX",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": "Information is not mine"
#                 },
#                 "sort": [
#                     1.0,
#                     "999958"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999957",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Mortgage",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Loan servicing, payments, escrow account",
#                     "sub_product": "FHA mortgage",
#                     "zip_code": "79057",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999957",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Phone",
#                     "company": "Dovenmuehle Mortgage, Inc.",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "TX",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999957"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99995",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Mortgage",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-08-28T12:00:00-05:00",
#                     "issue": "Credit decision / Underwriting",
#                     "sub_product": "Other mortgage",
#                     "zip_code": "80112",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "99995",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Postal mail",
#                     "company": "InterLinc Mortgage Services, LLC",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "CO",
#                     "consumer_disputed": "Yes",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99995"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999946",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Debt collection",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-09-02T12:00:00-05:00",
#                     "issue": "Cont'd attempts collect debt not owed",
#                     "sub_product": "Medical",
#                     "zip_code": "89434",
#                     "tags": "Servicemember",
#                     "has_narrative": false,
#                     "complaint_id": "999946",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with non-monetary relief",
#                     "submitted_via": "Web",
#                     "company": "Professional Finance Company, Inc.",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "NV",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": "Debt is not mine"
#                 },
#                 "sort": [
#                     1.0,
#                     "999946"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999944",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit card",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-25T12:00:00-05:00",
#                     "issue": "Billing disputes",
#                     "sub_product": null,
#                     "zip_code": "80828",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999944",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with monetary relief",
#                     "submitted_via": "Web",
#                     "company": "CAPITAL ONE FINANCIAL CORPORATION",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "CO",
#                     "consumer_disputed": "Yes",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999944"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999942",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Bank account or service",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Making/receiving payments, sending money",
#                     "sub_product": "Checking account",
#                     "zip_code": "92011",
#                     "tags": "Servicemember",
#                     "has_narrative": false,
#                     "complaint_id": "999942",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with monetary relief",
#                     "submitted_via": "Phone",
#                     "company": "UNITED SERVICES AUTOMOBILE ASSOCIATION",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "CA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999942"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99994",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit card",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-06-18T12:00:00-05:00",
#                     "issue": "Delinquent account",
#                     "sub_product": null,
#                     "zip_code": "20746",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "99994",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Web",
#                     "company": "CAPITAL ONE FINANCIAL CORPORATION",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "MD",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99994"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999934",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Debt collection",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Disclosure verification of debt",
#                     "sub_product": "Other (i.e. phone, health club, etc.)",
#                     "zip_code": "92301",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999934",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Postal mail",
#                     "company": "Diversified Consultants, Inc.",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "CA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": "Not given enough info to verify debt"
#                 },
#                 "sort": [
#                     1.0,
#                     "999934"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99993",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Consumer Loan",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-06-14T12:00:00-05:00",
#                     "issue": "Managing the loan or lease",
#                     "sub_product": "Installment loan",
#                     "zip_code": "48021",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "99993",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with non-monetary relief",
#                     "submitted_via": "Phone",
#                     "company": "BANK OF AMERICA, NATIONAL ASSOCIATION",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "MI",
#                     "consumer_disputed": "Yes",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99993"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999926",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit card",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-25T12:00:00-05:00",
#                     "issue": "Delinquent account",
#                     "sub_product": null,
#                     "zip_code": "30318",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999926",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Web",
#                     "company": "CAPITAL ONE FINANCIAL CORPORATION",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "GA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999926"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99991",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Mortgage",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-06-15T12:00:00-05:00",
#                     "issue": "Settlement process and costs",
#                     "sub_product": "FHA mortgage",
#                     "zip_code": "08831",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "99991",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Web",
#                     "company": "JPMORGAN CHASE & CO.",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "NJ",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99991"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999908",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Debt collection",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Cont'd attempts collect debt not owed",
#                     "sub_product": "Mortgage",
#                     "zip_code": "33770",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999908",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Fax",
#                     "company": "NATIONSTAR MORTGAGE",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "FL",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": "Debt was paid"
#                 },
#                 "sort": [
#                     1.0,
#                     "999908"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999904",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Bank account or service",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Account opening, closing, or management",
#                     "sub_product": "Other bank product/service",
#                     "zip_code": "17325",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999904",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with monetary relief",
#                     "submitted_via": "Fax",
#                     "company": "TD BANK US HOLDING COMPANY",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "PA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999904"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999902",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Money transfers",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Other transaction issues",
#                     "sub_product": "International money transfer",
#                     "zip_code": "70705",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999902",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Phone",
#                     "company": "BANK OF AMERICA, NATIONAL ASSOCIATION",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "MD",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999902"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999897",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit card",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Customer service / Customer relations",
#                     "sub_product": null,
#                     "zip_code": "29651",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999897",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Web",
#                     "company": "SYNCHRONY FINANCIAL",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "SC",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999897"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "99989",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit card",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2012-06-18T12:00:00-05:00",
#                     "issue": "Billing disputes",
#                     "sub_product": null,
#                     "zip_code": "94127",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "99989",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with non-monetary relief",
#                     "submitted_via": "Phone",
#                     "company": "JPMORGAN CHASE & CO.",
#                     "date_received": "2012-06-12T12:00:00-05:00",
#                     "state": "CA",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "99989"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999887",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Mortgage",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-08-28T12:00:00-05:00",
#                     "issue": "Loan servicing, payments, escrow account",
#                     "sub_product": "Conventional fixed mortgage",
#                     "zip_code": "21801",
#                     "tags": "Older American, Servicemember",
#                     "has_narrative": false,
#                     "complaint_id": "999887",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Phone",
#                     "company": "WELLS FARGO & COMPANY",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "MD",
#                     "consumer_disputed": "Yes",
#                     "company_public_response": null,
#                     "sub_issue": null
#                 },
#                 "sort": [
#                     1.0,
#                     "999887"
#                 ]
#             },
#             {
#                 "_index": "complaint-public-v1",
#                 "_type": "_doc",
#                 "_id": "999878",
#                 "_score": 1.0,
#                 "_source": {
#                     "product": "Credit reporting",
#                     "complaint_what_happened": "",
#                     "date_sent_to_company": "2014-09-08T12:00:00-05:00",
#                     "issue": "Credit monitoring or identity protection",
#                     "sub_product": null,
#                     "zip_code": "11433",
#                     "tags": null,
#                     "has_narrative": false,
#                     "complaint_id": "999878",
#                     "timely": "Yes",
#                     "consumer_consent_provided": "N/A",
#                     "company_response": "Closed with explanation",
#                     "submitted_via": "Postal mail",
#                     "company": "EQUIFAX, INC.",
#                     "date_received": "2014-08-25T12:00:00-05:00",
#                     "state": "NY",
#                     "consumer_disputed": "No",
#                     "company_public_response": null,
#                     "sub_issue": "Account terms and changes"
#                 },
#                 "sort": [
#                     1.0,
#                     "999878"
#                 ]
#             }
#         ]
#     },
#     "aggregations": {
#         "has_narrative": {
#             "meta": {},
#             "doc_count": 3093136,
#             "has_narrative": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 0,
#                 "buckets": [
#                     {
#                         "key": 0,
#                         "key_as_string": "false",
#                         "doc_count": 1981806
#                     },
#                     {
#                         "key": 1,
#                         "key_as_string": "true",
#                         "doc_count": 1111330
#                     }
#                 ]
#             }
#         },
#         "product": {
#             "meta": {},
#             "doc_count": 3093136,
#             "product": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 0,
#                 "buckets": [
#                     {
#                         "key": "Credit reporting, credit repair services, or other personal consumer reports",
#                         "doc_count": 1425000,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "Credit reporting",
#                                     "doc_count": 1408816
#                                 },
#                                 {
#                                     "key": "Other personal consumer report",
#                                     "doc_count": 12723
#                                 },
#                                 {
#                                     "key": "Credit repair services",
#                                     "doc_count": 3460
#                                 },
#                                 {
#                                     "key": "Conventional home mortgage",
#                                     "doc_count": 1
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "key": "Debt collection",
#                         "doc_count": 452129,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "I do not know",
#                                     "doc_count": 98773
#                                 },
#                                 {
#                                     "key": "Other debt",
#                                     "doc_count": 84209
#                                 },
#                                 {
#                                     "key": "Credit card debt",
#                                     "doc_count": 72464
#                                 },
#                                 {
#                                     "key": "Medical debt",
#                                     "doc_count": 47593
#                                 },
#                                 {
#                                     "key": "Other (i.e. phone, health club, etc.)",
#                                     "doc_count": 44541
#                                 },
#                                 {
#                                     "key": "Credit card",
#                                     "doc_count": 28694
#                                 },
#                                 {
#                                     "key": "Medical",
#                                     "doc_count": 21186
#                                 },
#                                 {
#                                     "key": "Auto debt",
#                                     "doc_count": 12016
#                                 },
#                                 {
#                                     "key": "Payday loan debt",
#                                     "doc_count": 8339
#                                 },
#                                 {
#                                     "key": "Payday loan",
#                                     "doc_count": 7558
#                                 },
#                                 {
#                                     "key": "Mortgage debt",
#                                     "doc_count": 5733
#                                 },
#                                 {
#                                     "key": "Mortgage",
#                                     "doc_count": 4809
#                                 },
#                                 {
#                                     "key": "Auto",
#                                     "doc_count": 3755
#                                 },
#                                 {
#                                     "key": "Federal student loan debt",
#                                     "doc_count": 3569
#                                 },
#                                 {
#                                     "key": "Private student loan debt",
#                                     "doc_count": 3535
#                                 },
#                                 {
#                                     "key": "Non-federal student loan",
#                                     "doc_count": 2880
#                                 },
#                                 {
#                                     "key": "Federal student loan",
#                                     "doc_count": 2475
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "key": "Mortgage",
#                         "doc_count": 364992,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "Other mortgage",
#                                     "doc_count": 86635
#                                 },
#                                 {
#                                     "key": "Conventional home mortgage",
#                                     "doc_count": 84404
#                                 },
#                                 {
#                                     "key": "Conventional fixed mortgage",
#                                     "doc_count": 70613
#                                 },
#                                 {
#                                     "key": "FHA mortgage",
#                                     "doc_count": 45099
#                                 },
#                                 {
#                                     "key": "Conventional adjustable mortgage (ARM)",
#                                     "doc_count": 25380
#                                 },
#                                 {
#                                     "key": "Other type of mortgage",
#                                     "doc_count": 14613
#                                 },
#                                 {
#                                     "key": "VA mortgage",
#                                     "doc_count": 13774
#                                 },
#                                 {
#                                     "key": "Home equity loan or line of credit",
#                                     "doc_count": 11624
#                                 },
#                                 {
#                                     "key": "Home equity loan or line of credit (HELOC)",
#                                     "doc_count": 8057
#                                 },
#                                 {
#                                     "key": "Reverse mortgage",
#                                     "doc_count": 4131
#                                 },
#                                 {
#                                     "key": "Second mortgage",
#                                     "doc_count": 662
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "key": "Credit card or prepaid card",
#                         "doc_count": 165069,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "General-purpose credit card or charge card",
#                                     "doc_count": 125230
#                                 },
#                                 {
#                                     "key": "Store credit card",
#                                     "doc_count": 23566
#                                 },
#                                 {
#                                     "key": "Government benefit card",
#                                     "doc_count": 8047
#                                 },
#                                 {
#                                     "key": "General-purpose prepaid card",
#                                     "doc_count": 6779
#                                 },
#                                 {
#                                     "key": "Payroll card",
#                                     "doc_count": 714
#                                 },
#                                 {
#                                     "key": "Gift card",
#                                     "doc_count": 705
#                                 },
#                                 {
#                                     "key": "Student prepaid card",
#                                     "doc_count": 25
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "key": "Checking or savings account",
#                         "doc_count": 141523,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "Checking account",
#                                     "doc_count": 112126
#                                 },
#                                 {
#                                     "key": "Other banking product or service",
#                                     "doc_count": 16219
#                                 },
#                                 {
#                                     "key": "Savings account",
#                                     "doc_count": 9928
#                                 },
#                                 {
#                                     "key": "CD (Certificate of Deposit)",
#                                     "doc_count": 3156
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "key": "Credit reporting",
#                         "doc_count": 140430,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": []
#                         }
#                     },
#                     {
#                         "key": "Credit card",
#                         "doc_count": 89190,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": []
#                         }
#                     },
#                     {
#                         "key": "Bank account or service",
#                         "doc_count": 86206,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "Checking account",
#                                     "doc_count": 59045
#                                 },
#                                 {
#                                     "key": "Other bank product/service",
#                                     "doc_count": 17825
#                                 },
#                                 {
#                                     "key": "Savings account",
#                                     "doc_count": 5294
#                                 },
#                                 {
#                                     "key": "(CD) Certificate of deposit",
#                                     "doc_count": 3417
#                                 },
#                                 {
#                                     "key": "Cashing a check without an account",
#                                     "doc_count": 625
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "key": "Student loan",
#                         "doc_count": 71450,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "Federal student loan servicing",
#                                     "doc_count": 36043
#                                 },
#                                 {
#                                     "key": "Non-federal student loan",
#                                     "doc_count": 22283
#                                 },
#                                 {
#                                     "key": "Private student loan",
#                                     "doc_count": 13124
#                                 }
#                             ]
#                         }
#                     },
#                     {
#                         "key": "Money transfer, virtual currency, or money service",
#                         "doc_count": 47526,
#                         "sub_product.raw": {
#                             "doc_count_error_upper_bound": 0,
#                             "sum_other_doc_count": 0,
#                             "buckets": [
#                                 {
#                                     "key": "Mobile or digital wallet",
#                                     "doc_count": 17322
#                                 },
#                                 {
#                                     "key": "Domestic (US) money transfer",
#                                     "doc_count": 12818
#                                 },
#                                 {
#                                     "key": "Virtual currency",
#                                     "doc_count": 7458
#                                 },
#                                 {
#                                     "key": "International money transfer",
#                                     "doc_count": 6143
#                                 },
# ...
#                 "buckets": [
#                     {
#                         "key": "Consent provided",
#                         "doc_count": 1111966
#                     },
#                     {
#                         "key": "Consent not provided",
#                         "doc_count": 1073800
#                     },
#                     {
#                         "key": "N/A",
#                         "doc_count": 721373
#                     },
#                     {
#                         "key": "Other",
#                         "doc_count": 82484
#                     },
#                     {
#                         "key": "Consent withdrawn",
#                         "doc_count": 5268
#                     }
#                 ]
#             }
#         },
#         "company_response": {
#             "meta": {},
#             "doc_count": 3093136,
#             "company_response": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 0,
#                 "buckets": [
#                     {
#                         "key": "Closed with explanation",
#                         "doc_count": 2398508
#                     },
#                     {
#                         "key": "Closed with non-monetary relief",
#                         "doc_count": 457251
#                     },
#                     {
#                         "key": "Closed with monetary relief",
#                         "doc_count": 122975
#                     },
#                     {
#                         "key": "In progress",
#                         "doc_count": 64291
#                     },
#                     {
#                         "key": "Closed without relief",
#                         "doc_count": 17868
#                     },
#                     {
#                         "key": "Closed",
#                         "doc_count": 17611
#                     },
#                     {
#                         "key": "Untimely response",
#                         "doc_count": 9324
#                     },
#                     {
#                         "key": "Closed with relief",
#                         "doc_count": 5304
#                     }
#                 ]
#             }
#         },
#         "submitted_via": {
#             "meta": {},
#             "doc_count": 3093136,
#             "submitted_via": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 0,
#                 "buckets": [
#                     {
#                         "key": "Web",
#                         "doc_count": 2596446
#                     },
#                     {
#                         "key": "Referral",
#                         "doc_count": 237171
#                     },
#                     {
#                         "key": "Phone",
#                         "doc_count": 146810
#                     },
#                     {
#                         "key": "Postal mail",
#                         "doc_count": 86180
#                     },
#                     {
#                         "key": "Fax",
#                         "doc_count": 25660
#                     },
#                     {
#                         "key": "Web Referral",
#                         "doc_count": 445
#                     },
#                     {
#                         "key": "Email",
#                         "doc_count": 424
#                     }
#                 ]
#             }
#         },
#         "state": {
#             "meta": {},
#             "doc_count": 3093136,
#             "state": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 0,
#                 "buckets": [
#                     {
#                         "key": "CA",
#                         "doc_count": 377769
#                     },
#                     {
#                         "key": "FL",
#                         "doc_count": 346151
#                     },
#                     {
#                         "key": "TX",
#                         "doc_count": 301432
#                     },
#                     {
#                         "key": "NY",
#                         "doc_count": 202376
#                     },
#                     {
#                         "key": "GA",
#                         "doc_count": 194134
#                     },
#                     {
#                         "key": "PA",
#                         "doc_count": 139681
#                     },
#                     {
#                         "key": "IL",
#                         "doc_count": 117741
#                     },
#                     {
#                         "key": "NJ",
#                         "doc_count": 106297
#                     },
#                     {
#                         "key": "NC",
#                         "doc_count": 97356
#                     },
#                     {
#                         "key": "OH",
#                         "doc_count": 83258
#                     },
#                     {
#                         "key": "MD",
#                         "doc_count": 82990
#                     },
#                     {
#                         "key": "VA",
#                         "doc_count": 79050
#                     },
#                     {
#                         "key": "MI",
#                         "doc_count": 68510
#                     },
#                     {
#                         "key": "TN",
#                         "doc_count": 60525
#                     },
#                     {
#                         "key": "AL",
#                         "doc_count": 57110
#                     },
#                     {
#                         "key": "AZ",
#                         "doc_count": 56786
#                     },
#                     {
#                         "key": "SC",
#                         "doc_count": 54261
#                     },
#                     {
#                         "key": "LA",
#                         "doc_count": 49112
#                     },
#                     {
#                         "key": "MA",
#                         "doc_count": 48955
#                     },
#                     {
#                         "key": "WA",
#                         "doc_count": 43767
#                     },
#                     {
#                         "key": "NV",
#                         "doc_count": 41911
#                     },
#                     {
#                         "key": "MO",
#                         "doc_count": 40082
#                     },
#                     {
#                         "key": "CO",
#                         "doc_count": 37888
#                     },
#                     {
#                         "key": "IN",
#                         "doc_count": 31463
#                     },
#                     {
#                         "key": "CT",
#                         "doc_count": 28219
#                     },
#                     {
#                         "key": "MN",
#                         "doc_count": 26304
#                     },
#                     {
#                         "key": "WI",
#                         "doc_count": 26052
#                     },
#                     {
#                         "key": "MS",
#                         "doc_count": 23938
#                     },
#                     {
#                         "key": "OR",
#                         "doc_count": 21960
#                     },
#                     {
#                         "key": "AR",
#                         "doc_count": 21267
#                     },
#                     {
#                         "key": "UT",
#                         "doc_count": 17727
#                     },
#                     {
#                         "key": "KY",
#                         "doc_count": 17509
#                     },
#                     {
#                         "key": "OK",
#                         "doc_count": 17070
#                     },
#                     {
#                         "key": "DE",
#                         "doc_count": 15629
#                     },
#                     {
#                         "key": "DC",
#                         "doc_count": 14115
#                     },
#                     {
#                         "key": "KS",
#                         "doc_count": 11769
#                     },
#                     {
#                         "key": "IA",
#                         "doc_count": 9869
#                     },
#                     {
#                         "key": "NM",
#                         "doc_count": 9814
#                     },
#                     {
#                         "key": "PR",
#                         "doc_count": 7935
#                     },
#                     {
#                         "key": "RI",
#                         "doc_count": 7424
#                     },
#                     {
#                         "key": "NH",
#                         "doc_count": 7411
#                     },
#                     {
#                         "key": "HI",
#                         "doc_count": 7214
#                     },
#                     {
#                         "key": "ID",
#                         "doc_count": 6662
#                     },
#                     {
#                         "key": "NE",
#                         "doc_count": 6417
#                     },
#                     {
#                         "key": "ME",
#                         "doc_count": 5704
#                     },
#                     {
#                         "key": "WV",
#                         "doc_count": 5565
#                     },
#                     {
#                         "key": "MT",
#                         "doc_count": 3674
#                     },
#                     {
#                         "key": "AK",
#                         "doc_count": 2830
#                     },
#                     {
#                         "key": "VT",
#                         "doc_count": 2633
#                     },
#                     {
#                         "key": "SD",
#                         "doc_count": 2574
#                     },
#                     {
#                         "key": "ND",
#                         "doc_count": 2261
#                     },
#                     {
#                         "key": "WY",
#                         "doc_count": 2113
#                     },
#                     {
#                         "key": "AE",
#                         "doc_count": 889
#                     },
#                     {
#                         "key": "VI",
#                         "doc_count": 592
#                     },
#                     {
#                         "key": "AP",
#                         "doc_count": 583
#                     },
#                     {
#                         "key": "GU",
#                         "doc_count": 258
#                     },
#                     {
#                         "key": "UNITED STATES MINOR OUTLYING ISLANDS",
#                         "doc_count": 256
#                     },
#                     {
#                         "key": "FM",
#                         "doc_count": 115
#                     },
#                     {
#                         "key": "AA",
#                         "doc_count": 50
#                     },
#                     {
#                         "key": "MP",
#                         "doc_count": 44
#                     },
#                     {
#                         "key": "AS",
#                         "doc_count": 38
#                     },
#                     {
#                         "key": "MH",
#                         "doc_count": 33
#                     },
#                     {
#                         "key": "PW",
#                         "doc_count": 13
#                     }
#                 ]
#             }
#         },
#         "consumer_disputed": {
#             "meta": {},
#             "doc_count": 3093136,
#             "consumer_disputed": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 0,
#                 "buckets": [
#                     {
#                         "key": "N/A",
#                         "doc_count": 2324693
#                     },
#                     {
#                         "key": "No",
#                         "doc_count": 620065
#                     },
#                     {
#                         "key": "Yes",
#                         "doc_count": 148378
#                     }
#                 ]
#             }
#         },
#         "company_public_response": {
#             "meta": {},
#             "doc_count": 3093136,
#             "company_public_response": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 98,
#                 "buckets": [
#                     {
#                         "key": "Company has responded to the consumer and the CFPB and chooses not to provide a public response",
#                         "doc_count": 1136629
#                     },
#                     {
#                         "key": "Company believes it acted appropriately as authorized by contract or law",
#                         "doc_count": 111930
#                     },
#                     {
#                         "key": "Company chooses not to provide a public response",
#                         "doc_count": 52473
#                     },
#                     {
#                         "key": "Company believes the complaint is the result of a misunderstanding",
#                         "doc_count": 11002
#                     },
#                     {
#                         "key": "Company disputes the facts presented in the complaint",
#                         "doc_count": 8934
#                     },
#                     {
#                         "key": "Company believes complaint caused principally by actions of third party outside the control or direction of the company",
#                         "doc_count": 6944
#                     },
#                     {
#                         "key": "Company believes complaint is the result of an isolated error",
#                         "doc_count": 5638
#                     },
#                     {
#                         "key": "Company believes complaint represents an opportunity for improvement to better serve consumers",
#                         "doc_count": 4223
#                     },
#                     {
#                         "key": "Company can't verify or dispute the facts in the complaint",
#                         "doc_count": 3850
#                     },
#                     {
#                         "key": "Company believes the complaint provided an opportunity to answer consumer's questions",
#                         "doc_count": 2535
#                     }
#                 ]
#             }
#         },
#         "tags": {
#             "meta": {},
#             "doc_count": 3093136,
#             "tags": {
#                 "doc_count_error_upper_bound": 0,
#                 "sum_other_doc_count": 0,
#                 "buckets": [
#                     {
#                         "key": "Servicemember",
#                         "doc_count": 194513
#                     },
#                     {
#                         "key": "Older American",
#                         "doc_count": 126530
#                     },
#                     {
#                         "key": "Older American, Servicemember",
#                         "doc_count": 29672
#                     }
#                 ]
#             }
#         }
#     },
#     "_meta": {
#         "license": "CC0",
#         "last_updated": "2022-11-21T12:00:00-05:00",
#         "last_indexed": "2022-11-22T12:00:00-05:00",
#         "total_record_count": 3093136,
#         "is_data_stale": false,
#         "has_data_issue": false,
#         "break_points": {
#             "2": [
#                 1.0,
#                 "999878"
#             ],
#             "3": [
#                 1.0,
#                 "99976"
#             ],
#             "4": [
#                 1.0,
#                 "999652"
#             ],
#             "5": [
#                 1.0,
#                 "999589"
#             ],
#             "6": [
#                 1.0,
#                 "999492"
#             ],
#             "7": [
#                 1.0,
#                 "999398"
#             ],
#             "8": [
#                 1.0,
#                 "99928"
#             ]
#         }
#     }
# }

# %%
# Print the first 100 characters or specific keys from the JSON file
with open(file_path, 'r') as f:
    data = json.load(f)

# Print only a part of the data to inspect the structure
print(json.dumps(data)[:500])  # Adjust the slice as needed

# Alternatively, print just the keys
if isinstance(data, dict):
    print(data.keys())
elif isinstance(data, list):
    print(data[0].keys())  # Assuming it's a list of dictionaries
# Out:
# {"took": 1373, "timed_out": false, "_shards": {"total": 5, "successful": 5, "skipped": 0, "failed": 0}, "hits": {"total": {"value": 3093136, "relation": "eq"}, "max_score": null, "hits": [{"_index": "complaint-public-v1", "_type": "_doc", "_id": "99999", "_score": 1.0, "_source": {"product": "Bank account or service", "complaint_what_happened": "", "date_sent_to_company": "2013-11-18T12:00:00-05:00", "issue": "Deposits and withdrawals", "sub_product": "Checking account", "zip_code": "94605", "ta
# dict_keys(['took', 'timed_out', '_shards', 'hits', 'aggregations', '_meta'])

# %%
# Extract the list of complaint records from 'hits'
complaint_records = data['hits']['hits']

# %%
# Flatten the nested JSON into a DataFrame (extracting fields from '_source')
df = pd.json_normalize(complaint_records, sep='_', record_path=None, 
                       meta=['_id', '_score', '_index'], 
                       meta_prefix='meta_', errors='ignore')

# %%
# Focus only on the fields inside '_source'
df = df[df.columns[df.columns.str.startswith('_source')]]

# %%
# Flatten the '_source' field itself
df.columns = df.columns.str.replace('_source.', '')

# %%
df.head()
# Out:
#            _source_product _source_complaint_what_happened  \
# 0  Bank account or service
# 1          Debt collection
# 2                 Mortgage
# 3              Credit card
# 4  Bank account or service
#
#   _source_date_sent_to_company                             _source_issue  \
# 0    2013-11-18T12:00:00-05:00                  Deposits and withdrawals
# 1    2014-09-04T12:00:00-05:00                     Communication tactics
# 2    2014-08-28T12:00:00-05:00  Application, originator, mortgage broker
# 3    2012-06-15T12:00:00-05:00                 Advertising and marketing
# 4    2012-06-21T12:00:00-05:00     Problems caused by my funds being low
#
#            _source_sub_product _source_zip_code  \
# 0             Checking account            94605
# 1                I do not know            93305
# 2  Conventional fixed mortgage            32818
# 3                         None            98221
# 4             Checking account            19140
#
#                     _source_tags  _source_has_narrative _source_complaint_id  \
# 0                 Older American                  False                99999
# 1                           None                  False               999988
# 2                           None                  False               999986
# 3                 Older American                  False                99998
# 4  Older American, Servicemember                  False                99997
#
#   _source_timely _source_consumer_consent_provided _source_company_response  \
# 0            Yes                               N/A  Closed with explanation
# 1            Yes                               N/A                   Closed
# 2            Yes                               N/A  Closed with explanation
# 3            Yes                               N/A  Closed with explanation
# 4            Yes                               N/A                   Closed
#
#   _source_submitted_via                       _source_company  \
# 0                 Phone                 WELLS FARGO & COMPANY
# 1                   Web         Kimball, Tirey & St. John LLP
# 2                 Phone                  JPMORGAN CHASE & CO.
# 3                   Web     CAPITAL ONE FINANCIAL CORPORATION
# 4           Postal mail  SANTANDER BANK, NATIONAL ASSOCIATION
#
#        _source_date_received _source_state _source_consumer_disputed  \
# 0  2012-06-12T12:00:00-05:00            CA                        No
# 1  2014-08-25T12:00:00-05:00            CA                        No
# 2  2014-08-25T12:00:00-05:00            FL                       Yes
# 3  2012-06-12T12:00:00-05:00            WA                        No
# 4  2012-06-12T12:00:00-05:00            PA                        No
#
#   _source_company_public_response                      _source_sub_issue
# 0                            None                                   None
# 1                            None  Used obscene/profane/abusive language
# 2                            None                                   None
# 3                            None                                   None
# 4                            None                                   None

# %%
df.shape
# Out:
# (25, 19)

# %%
df.columns
# Out:
# Index(['_source_product', '_source_complaint_what_happened',
#        '_source_date_sent_to_company', '_source_issue', '_source_sub_product',
#        '_source_zip_code', '_source_tags', '_source_has_narrative',
#        '_source_complaint_id', '_source_timely',
#        '_source_consumer_consent_provided', '_source_company_response',
#        '_source_submitted_via', '_source_company', '_source_date_received',
#        '_source_state', '_source_consumer_disputed',
#        '_source_company_public_response', '_source_sub_issue'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _source_product                    25 non-null     object
#  1   _source_complaint_what_happened    25 non-null     object
#  2   _source_date_sent_to_company       25 non-null     object
#  3   _source_issue                      25 non-null     object
#  4   _source_sub_product                16 non-null     object
#  5   _source_zip_code                   25 non-null     object
#  6   _source_tags                       7 non-null      object
#  7   _source_has_narrative              25 non-null     bool
#  8   _source_complaint_id               25 non-null     object
#  9   _source_timely                     25 non-null     object
#  10  _source_consumer_consent_provided  25 non-null     object
#  11  _source_company_response           25 non-null     object
#  12  _source_submitted_via              25 non-null     object
#  13  _source_company                    25 non-null     object
#  14  _source_date_received              25 non-null     object
#  15  _source_state                      25 non-null     object
#  16  _source_consumer_disputed          25 non-null     object
#  17  _source_company_public_response    0 non-null      object
#  18  _source_sub_issue                  7 non-null      object
# dtypes: bool(1), object(18)
# memory usage: 3.7+ KB

# %%
df.isnull().sum()
# Out:
# _source_product                       0
# _source_complaint_what_happened       0
# _source_date_sent_to_company          0
# _source_issue                         0
# _source_sub_product                   9
# _source_zip_code                      0
# _source_tags                         18
# _source_has_narrative                 0
# _source_complaint_id                  0
# _source_timely                        0
# _source_consumer_consent_provided     0
# _source_company_response              0
# _source_submitted_via                 0
# _source_company                       0
# _source_date_received                 0
# _source_state                         0
# _source_consumer_disputed             0
# _source_company_public_response      25
# _source_sub_issue                    18
# dtype: int64

# %%
missing_percentage = df.isnull().sum() / len(df) * 100
print(missing_percentage)
# Out:
# _source_product                        0.0
# _source_complaint_what_happened        0.0
# _source_date_sent_to_company           0.0
# _source_issue                          0.0
# _source_sub_product                   36.0
# _source_zip_code                       0.0
# _source_tags                          72.0
# _source_has_narrative                  0.0
# _source_complaint_id                   0.0
# _source_timely                         0.0
# _source_consumer_consent_provided      0.0
# _source_company_response               0.0
# _source_submitted_via                  0.0
# _source_company                        0.0
# _source_date_received                  0.0
# _source_state                          0.0
# _source_consumer_disputed              0.0
# _source_company_public_response      100.0
# _source_sub_issue                     72.0
# dtype: float64

# %%
# Option 1: Drop rows with missing values in specific columns
df = df.dropna(subset=['_source_date_sent_to_company'])

# Option 2: Fill missing values in categorical fields with 'Unknown'
df['_source_sub_product'] = df['_source_sub_product'].fillna('Unknown')

# Option 3: Drop columns with too many missing values (if necessary)
df = df.drop(columns=['_source_sub_issue'], errors='ignore')

# %%
# Check for duplicates
duplicates = df.duplicated()
print(f"Number of duplicate rows: {duplicates.sum()}")

# Drop duplicate rows if necessary
df = df.drop_duplicates()
# Out:
# Number of duplicate rows: 0

# %%
# Convert the 'date_sent_to_company' column to datetime
df['_source_date_sent_to_company'] = pd.to_datetime(df['_source_date_sent_to_company'], errors='coerce')

# Check for any remaining rows with invalid dates
df = df.dropna(subset=['_source_date_sent_to_company'])

# Clean categorical columns (e.g., product categories)
df['_source_product'] = df['_source_product'].str.strip().str.lower()

# %%
# Example: Detect outliers in numeric fields (if applicable)
df['_source_complaint_id'] = pd.to_numeric(df['_source_complaint_id'], errors='coerce')

# You can plot or inspect summary statistics to detect outliers
df['_source_complaint_id'].describe()
# Out:
# count        25.000000
# mean     675955.000000
# std      440877.791061
# min       99989.000000
# 25%       99997.000000
# 50%      999902.000000
# 75%      999944.000000
# max      999988.000000
# Name: _source_complaint_id, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   _source_product                    25 non-null     object
#  1   _source_complaint_what_happened    25 non-null     object
#  2   _source_date_sent_to_company       25 non-null     datetime64[ns, UTC-05:00]
#  3   _source_issue                      25 non-null     object
#  4   _source_sub_product                25 non-null     object
#  5   _source_zip_code                   25 non-null     object
#  6   _source_tags                       7 non-null      object
#  7   _source_has_narrative              25 non-null     bool
#  8   _source_complaint_id               25 non-null     int64
#  9   _source_timely                     25 non-null     object
#  10  _source_consumer_consent_provided  25 non-null     object
#  11  _source_company_response           25 non-null     object
#  12  _source_submitted_via              25 non-null     object
#  13  _source_company                    25 non-null     object
#  14  _source_date_received              25 non-null     object
#  15  _source_state                      25 non-null     object
#  16  _source_consumer_disputed          25 non-null     object
#  17  _source_company_public_response    0 non-null      object
# dtypes: bool(1), datetime64[ns, UTC-05:00](1), int64(1), object(15)
# memory usage: 3.5+ KB

# %%
df.head()
# Out:
#            _source_product _source_complaint_what_happened  \
# 0  bank account or service
# 1          debt collection
# 2                 mortgage
# 3              credit card
# 4  bank account or service
#
#   _source_date_sent_to_company                             _source_issue  \
# 0    2013-11-18 12:00:00-05:00                  Deposits and withdrawals
# 1    2014-09-04 12:00:00-05:00                     Communication tactics
# 2    2014-08-28 12:00:00-05:00  Application, originator, mortgage broker
# 3    2012-06-15 12:00:00-05:00                 Advertising and marketing
# 4    2012-06-21 12:00:00-05:00     Problems caused by my funds being low
#
#            _source_sub_product _source_zip_code  \
# 0             Checking account            94605
# 1                I do not know            93305
# 2  Conventional fixed mortgage            32818
# 3                      Unknown            98221
# 4             Checking account            19140
#
#                     _source_tags  _source_has_narrative  _source_complaint_id  \
# 0                 Older American                  False                 99999
# 1                           None                  False                999988
# 2                           None                  False                999986
# 3                 Older American                  False                 99998
# 4  Older American, Servicemember                  False                 99997
#
#   _source_timely _source_consumer_consent_provided _source_company_response  \
# 0            Yes                               N/A  Closed with explanation
# 1            Yes                               N/A                   Closed
# 2            Yes                               N/A  Closed with explanation
# 3            Yes                               N/A  Closed with explanation
# 4            Yes                               N/A                   Closed
#
#   _source_submitted_via                       _source_company  \
# 0                 Phone                 WELLS FARGO & COMPANY
# 1                   Web         Kimball, Tirey & St. John LLP
# 2                 Phone                  JPMORGAN CHASE & CO.
# 3                   Web     CAPITAL ONE FINANCIAL CORPORATION
# 4           Postal mail  SANTANDER BANK, NATIONAL ASSOCIATION
#
#        _source_date_received _source_state _source_consumer_disputed  \
# 0  2012-06-12T12:00:00-05:00            CA                        No
# 1  2014-08-25T12:00:00-05:00            CA                        No
# 2  2014-08-25T12:00:00-05:00            FL                       Yes
# 3  2012-06-12T12:00:00-05:00            WA                        No
# 4  2012-06-12T12:00:00-05:00            PA                        No
#
#   _source_company_public_response
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None

# %%
# Save the cleaned DataFrame to a JSON file
output_file_path = r'C:\Users\Zana\Desktop\portfolio_projects\project_4\cleaned_complaints.json'
df.to_json(output_file_path, orient='records', date_format='iso')
print(f"Cleaned data has been saved to {output_file_path}")
# Out:
# Cleaned data has been saved to C:\Users\Zana\Desktop\portfolio_projects\project_4\cleaned_complaints.json

# %% [markdown]
# ## Sample Output of Cleaned Dataset
#
# Below is a preview of the cleaned dataset after processing:
#
# | Product                    | Issue                          | Company Response       | State | Complaint ID | Timely Response | Submitted Via | Tags            |
# |----------------------------|-------------------------------|------------------------|-------|--------------|-----------------|---------------|-----------------|
# | Credit card                | Billing disputes              | Closed with explanation| CA    | 99999        | Yes             | Web           | Older American  |
# | Mortgage                   | Application, originator issue | Closed with relief     | FL    | 999988       | Yes             | Phone         | None            |
# | Debt collection            | Communication tactics         | Closed                | NY    | 999986       | No              | Postal mail   | Servicemember   |
# | Checking account           | Deposits and withdrawals      | Closed with explanation| TX    | 99998        | Yes             | Web           | None            |
#
# ### Data Quality Improvements:
# - **Missing Values**: Handled by filling with default or `Unknown`.
# - **Duplicates**: Removed 0 duplicates.
# - **Standardized Fields**: Cleaned categorical fields (e.g., state names, products).
#
# This cleaned dataset is now ready for analysis and further integration.
